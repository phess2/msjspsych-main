# %%
import pandas as pd 
import numpy as np 
from pathlib import Path
# %matplotlib inline

# %%
# import file 

data = list(Path("/Users/mcdermottspeakerarray/Documents/binaural_cocktail_party/msjspsych-main/experiment_word_recognition/data").glob("*.csv"))

# %%
df = pd.read_csv(data[0])

# %%
df[df["trial_type"] == "dictionary-text"].reset_index(drop=True)
# Out:
#      Unnamed: 0     rt     response response_str correct_response  trial_num  \
# 0             0  33746     students      student         students        0.0
# 1             2  10490       appear       appear           appear        1.0
# 2             4   9338       travel       travel           travel        2.0
# 3             6  10722     complete     complete         complete        3.0
# 4             8   8479      hundred      hundred           groups        4.0
# ..          ...    ...          ...          ...              ...        ...
# 355         710   8140       played       Played           played      355.0
# 356         712  13575       matter       Matter           matter      356.0
# 357         714   8422     released     Released         released      357.0
# 358         716  13273        light        Light            light      358.0
# 359         718   8908  significant        Signi      significant      359.0
#
# ...
