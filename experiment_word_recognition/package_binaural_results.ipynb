# %%
import pandas as pd 
import numpy as np 
from pathlib import Path
# %matplotlib inline

# %%
# import file 

data = list(Path("/Users/mcdermottspeakerarray/Documents/binaural_cocktail_party/msjspsych-main/experiment_word_recognition/data/front_back_exp_v01").glob("*.csv"))

# %%
data
# Out:
# [PosixPath('/Users/mcdermottspeakerarray/Documents/binaural_cocktail_party/msjspsych-main/experiment_word_recognition/data/front_back_exp_v01/participant_001.csv')]

# %%
df = pd.read_csv(data[-1])

# %%
df[df["trial_type"] == "dictionary-text"].reset_index(drop=True)
# Out:
#      Unnamed: 0     rt      response response_str correct_response  trial_num  \
# 0             0  64243        market       Market           theory        0.0
# 1             2  33819         women        women            makes        1.0
# 2             4   9436        single       single           single        2.0
# 3             6  20340         parts        parts            place        3.0
# 4             8   8471         again        again            again        4.0
# ..          ...    ...           ...          ...              ...        ...
# 255         510   9689         forms        forms            forms      255.0
# 256         512  18294         after          aft            front      256.0
# 257         514   7923        future         futu           future      257.0
# 258         516   9988        should       should           should      258.0
# 259         518  20408  professional     professi            sound      259.0
#
# ...
