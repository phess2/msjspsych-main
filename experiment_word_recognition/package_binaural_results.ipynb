# %%
import pandas as pd 
import numpy as np 
from pathlib import Path
# %matplotlib inline

# %%
# import file 

data = list(Path("/Users/mcdermottspeakerarray/Documents/binaural_cocktail_party/msjspsych-main/experiment_word_recognition/data").glob("*.csv"))

# %%
data
# Out:
# [PosixPath('/Users/mcdermottspeakerarray/Documents/binaural_cocktail_party/msjspsych-main/experiment_word_recognition/data/ian_91_360.csv'),
#  PosixPath('/Users/mcdermottspeakerarray/Documents/binaural_cocktail_party/msjspsych-main/experiment_word_recognition/data/preston_pilot.csv'),
#  PosixPath('/Users/mcdermottspeakerarray/Documents/binaural_cocktail_party/msjspsych-main/experiment_word_recognition/data/ian_1_90.csv'),
#  PosixPath('/Users/mcdermottspeakerarray/Documents/binaural_cocktail_party/msjspsych-main/experiment_word_recognition/data/ian_pilot.csv')]

# %%
df = pd.read_csv(data[-1])

# %%
df[df["trial_type"] == "dictionary-text"].reset_index(drop=True)
# Out:
#      Unnamed: 0     rt  response response_str correct_response trial_num  \
# 0           0.0  26316  includes     Includes         includes       0.0
# 1           2.0  12341     small        Small            small       1.0
# 2           4.0  11188    reason       Reason           reason       2.0
# 3           6.0  10004   located      Located          located       3.0
# 4           8.0   8627     wrote        Wrote            wrote       4.0
# ..          ...    ...       ...          ...              ...       ...
# 355       530.0   7310    living       Living           living     355.0
# 356       532.0   9660   nothing        Nothi          nothing     356.0
# 357       534.0  25705     reach        Reach         released     357.0
# 358       536.0   7574     cover        Cover            cover     358.0
# 359       538.0  10741   already         Alre          already     359.0
#
#           trial_type trial_index time_elapsed internal_node_id correct  \
# 0    dictionary-text           0        26322      0.0-0.0-0.0     1.0
# 1    dictionary-text           2        40820      0.0-0.0-0.1     1.0
# 2    dictionary-text           4        54516      0.0-0.0-0.2     1.0
# 3    dictionary-text           6        67082      0.0-0.0-0.3     1.0
# 4    dictionary-text           8        77282      0.0-0.0-0.4     1.0
# ..               ...         ...          ...              ...     ...
# 355  dictionary-text         530      3327958    0.0-0.0-0.265     1.0
# 356  dictionary-text         532      3338287    0.0-0.0-0.266     1.0
# 357  dictionary-text         534      3365303    0.0-0.0-0.267     0.0
# 358  dictionary-text         536      3373803    0.0-0.0-0.268     1.0
# 359  dictionary-text         538      3386735    0.0-0.0-0.269     1.0
#
#     n_correct n_incorrect stimulus
# 0         1.0         0.0      NaN
# 1         2.0         0.0      NaN
# 2         3.0         0.0      NaN
# 3         4.0         0.0      NaN
# 4         5.0         0.0      NaN
# ..        ...         ...      ...
# 355     198.0        68.0      NaN
# 356     199.0        68.0      NaN
# 357     199.0        69.0      NaN
# 358     200.0        69.0      NaN
# 359     201.0        69.0      NaN
#
# [360 rows x 14 columns]
